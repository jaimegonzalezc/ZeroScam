# %% [markdown]
# # OCR
# He encontrado esta página de hugging face:
# https://huggingface.co/spaces/pragnakalp/OCR-image-to-text
# donde permite testear **PaddleOCR**, **EasyOCR** y **KerasOCR**.
#
# El input es esta imágen:

# %% [markdown]
# ![smishing_3.png](data:image/png;base64,...)

# %% [markdown]
# Salida de **PaddleOCR**:
# AT&T 3:06PM +1951)923-6938> Text Message MonJan 13,11:16 PM Amazon 2020 resolutions: 1) not to be greedy 2 care more about the customers So you'll qet $130 freebies to do a survey mate a2vcr.info/WYmoR8tOIPS O Text Message

# %% [markdown]
# Salida de **EasyOCR:**
# atat3:05 pn.4|951) 923-6938text messagemon, jan 13  11:16 pm amazon 2020 resolutions: 1) not to be greedy 2) care more about the customers  so you'll get $130 freebies to do a survey mate azvcr info/ w ymor8toipstext message

# %% [markdown]
# Salida de **KearasOCR**:
# atet 3106 pm 9511 236938 11 text message 15 1116 pm mon jan amazon 2020 resolutionst d not be greedy 2j to care the about customers more s130 so youll freebies get to do mate a survey infowymorstops a2vcr text message

# %% [markdown]
# Testeando otro modelo, **TesseractOCR**. El otput sigue siendo la misma imgágen y la salida ha sido esta:
#
# +1 (951) 923-6938
#
# Text Message
# Mon, Jan 13, 11:16 PM
#
# Amazon 2020 resolutions:
# 1) not to be greedy 2) care
# more about the customers.
# So you'll get $130 freebies
# to do a survey mate
# a2ver.info/WYmoR8tOlPS

# %% [markdown]
# Viendo los outputs de los 4 modelos, creo que el mejor para lo que necesitamos es TesseractOCR ya que consigue mantener el formato del sms y no incluye información relevante como la fecha y demás a parte de que conserva bien el formatod el número de teléfono así como el enlace.

# %% [markdown]
# Testeo con otra imágen, esta vez de un correo electrónico.

# %% [markdown]
# ![b767785e311a8f38967ad78f363f8b1b1ce6d68d.png](data:image/png;base64,...)

# %% [markdown]
# **Output**:
# Your PayPal Access Blocked ! 6
#
# PayPal <paypalaccounts@mailbox.com> Unsubscribe Feb 17, 2019, 4:50 PM *& rN :
# tome v
#
# Your PayPal Account is Limited,
# Solve in 24 Hours!
#
# Dear PayPal Customer,
#
# We're sorry to say you cannot access all the paypal account features like payment and money transfer.
# Click here to fix your account now. .
#
# Why is it blocked?
# Because we think your account is in danger of theft and unauthorized uses.
#
# How can | fix the problem?
# Confirm all your details on our server. Just click below and follow all of the steps.
#
# Confirm Account Details Now
